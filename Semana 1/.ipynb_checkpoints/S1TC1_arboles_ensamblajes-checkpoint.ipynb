# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Construcción e implementación de árboles de decisión y métodos de ensamblaje
#
# En este taller podrá poner en práctica los sus conocimientos sobre construcción e implementación de árboles de decisión y métodos de ensamblajes. El taller está constituido por 9 puntos, 5 relacionados con árboles de decisión (parte A) y 4 con métodos de ensamblaje (parte B).

# %% [markdown]
# ## Parte A - Árboles de decisión
#
# En esta parte del taller se usará el conjunto de datos de Capital Bikeshare de Kaggle, donde cada observación representa el alquiler de bicicletas durante una hora y día determinado. Para más detalles puede visitar los siguientes enlaces: [datos](https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip), [dicccionario de datos](https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset#).

# %% [markdown]
# ### Datos prestamo de bicicletas

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, export_graphviz
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.model_selection import GridSearchCV

# %%
# Lectura de la información de archivo .csv
bikes = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/bikeshare.csv', index_col='datetime', parse_dates=True)

# Renombrar variable "count" a "total"
bikes.rename(columns={'count':'total'}, inplace=True)

# Crear la hora como una variable 
bikes['hour'] = bikes.index.hour

# Visualización de los datos
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  total  hour
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16     0
# 2011-01-01 01:00:00        80        0.0       8          32     40     1
# 2011-01-01 02:00:00        80        0.0       5          27     32     2
# 2011-01-01 03:00:00        75        0.0       3          10     13     3
# 2011-01-01 04:00:00        75        0.0       0           1      1     4

# %% [markdown]
# ### Punto 1 - Análisis descriptivo
#
# Ejecute las celdas 1.1 y 1.2. A partir de los resultados realice un análisis descriptivo sobre las variables "season" y "hour", escriba sus inferencias sobre los datos. Para complementar su análisis puede usar métricas como máximo, mínimo, percentiles entre otros.

# %%
# Celda 1.1
bikes.groupby('season').total.mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: total, dtype: float64

# %% [markdown]
# Los resultados indican que, en promedio, las bicicletas fueron alquiladas en mayor cantidad durante la temporada 3 (verano), con una media de 234.4 alquileres. La temporada 2 (primavera) también tuvo una media alta de 215.3 alquileres, mientras que las temporadas 1 (invierno) y 4 (otoño) tuvieron medias más bajas de 116.3 y 199.0 alquileres, respectivamente.
#
# Esto sugiere que la temporada tiene un efecto significativo en la cantidad de bicicletas que se alquilan, con las temporadas más cálidas (primavera y verano) viendo un mayor número de alquileres en promedio.

# %%
# Celda 1.2
bikes.groupby('hour').total.mean()
# Out:
# hour
# 0      55.138462
# 1      33.859031
# 2      22.899554
# 3      11.757506
# 4       6.407240
# 5      19.767699
# 6      76.259341
# 7     213.116484
# 8     362.769231
# 9     221.780220
# 10    175.092308
# 11    210.674725
# 12    256.508772
# 13    257.787281
# 14    243.442982
# 15    254.298246
# 16    316.372807
# 17    468.765351
# 18    430.859649
# 19    315.278509
# 20    228.517544
# 21    173.370614
# 22    133.576754
# 23     89.508772
# Name: total, dtype: float64

# %%
estadis = bikes.groupby('season').total.describe()
estadis
# Out:
#          count        mean         std  min   25%    50%    75%    max
# season
# 1       2686.0  116.343261  125.273974  1.0  24.0   78.0  164.0  801.0
# 2       2733.0  215.251372  192.007843  1.0  49.0  172.0  321.0  873.0
# 3       2733.0  234.417124  197.151001  1.0  68.0  195.0  347.0  977.0
# 4       2734.0  198.988296  177.622409  1.0  51.0  161.0  294.0  948.0

# %% [markdown]
# se puede observar que la hora del día en que más se utiliza la bicicleta es entre las 5 y las 6 de la tarde. Sin embargo, también se presentan comportamientos crecientes con mayor uso de bicicletas apartir de las 4 am a 8 am y de 3 pm hasta las 5 pm, existen dos  picos en la demanda de bicicletas alrededor de las 8 am y 5 pm, lo que puede deberse a los horarios laborales o jornadas continuas.

# %% [markdown]
# Los valores mínimos para cada estación son de 1 bicicleta rentada, mientras que los valores máximos son diferentes en cada estación, siendo verano la estación con el pico máximo de 977 bicicletas rentadas. Además, el 75% de las observaciones se encuentran dentro de un rango diferente para cada estación, con el rango más amplio en la estación de verano.

# %% [markdown]
# ### Punto 2 - Análisis de gráficos
#
# Primero ejecute la celda 2.1 y asegúrese de comprender el código y el resultado. Luego, en cada una de celdas 2.2 y 2.3 escriba un código que genere una gráfica del número de bicicletas rentadas promedio para cada valor de la variable "hour" (hora) cuando la variable "season" es igual a 1 (invierno) e igual a 3 (verano), respectivamente. Analice y escriba sus hallazgos.

# %%
# Celda 2.1 - rentas promedio para cada valor de la variable "hour"
bikes.groupby('hour').total.mean().plot()
# Out:
# <AxesSubplot:xlabel='hour'>

# %%
# Celda 2.2 - "season"=1 escriba su código y hallazgos 

bikes_invierno = bikes[bikes['season'] == 1]
mean_bikes_invierno = bikes_invierno.groupby('hour').total.mean()

# %%
# Celda 2.3 - "season"=3 escriba su código y hallazgos

bikes_verano = bikes[bikes['season'] == 3]
mean_bikes_verano = bikes_verano.groupby('hour').total.mean()

# Crear la gráfica
plt.plot(mean_bikes_invierno.index, mean_bikes_invierno.values, label='Invierno')
plt.plot(mean_bikes_verano.index, mean_bikes_verano.values, label='Verano')
plt.xlabel('Hora')
plt.ylabel('Número de bicicletas rentadas promedio')
plt.title('Número de bicicletas rentadas promedio / hora y temporada')
plt.legend()
plt.show()

# %% [markdown]
# Se presentan las graficas para invierno (azul) y verano (naranja), en rasgos generales en verano se suele utilizar más la renta de bicicletas que en invierno, su comportamiento en similar atravez del dia en donde más se utiliza la bicicleta es entre las 5 y las 6 de la tarde. Sin embargo, también se presentan comportamientos crecientes con mayor uso de bicicletas apartir de las 4 am a 8 am y de 3 pm hasta las 5 pm y la unica hora donde su comportamiento aparenta ser igual es a las 4 am donde se rentan una media de 3 a 8 bicicletas en promedio.

# %% [markdown]
# ### Punto 3 - Regresión lineal
# En la celda 3 ajuste un modelo de regresión lineal a todo el conjunto de datos, utilizando "total" como variable de respuesta y "season" y "hour" como las únicas variables predictoras, teniendo en cuenta que la variable "season" es categórica. Luego, imprima los coeficientes e interprételos. ¿Cuáles son las limitaciones de la regresión lineal en este caso?

# %%
# Celda 3

dumm_season = pd.get_dummies(bikes['season'], prefix='season', drop_first=True)
X = pd.concat([dumm_season, bikes['hour']], axis=1)
y = bikes['total']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
reg = LinearRegression().fit(X_train, y_train)

# Predicción en los datos de entrenamiento
y_train_pred = reg.predict(X_train)

# Predicción en los datos de prueba
y_test_pred = reg.predict(X_test)

# Calcular el MSE en los datos de entrenamiento y prueba
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

print("El valor del MSE en los datos de entrenamiento es:", mse_train)
print("El valor del MSE en los datos de prueba es:", mse_test)
print('Coeficientes:', reg.coef_)
print('Término de intersección:', reg.intercept_)
# Out:
# El valor del MSE en los datos de entrenamiento es: 25217.5847744152
# El valor del MSE en los datos de prueba es: 26125.777378491017
# Coeficientes: [ 93.90358576 117.18612312  82.26842769  10.59316989]
# Término de intersección: -6.281122980728014

# %% [markdown]
# El coeficiente de "season_2" es de 93.8301836, lo que significa que en promedio, cuando todas las otras variables se mantienen constantes, el total de bicicletas alquiladas aumenta en 93.83 unidades cuando la temporada es primavera.
#
# El coeficiente de "season_3" es de 118.74065067, lo que significa que en promedio, cuando todas las otras variables se mantienen constantes, el total de bicicletas alquiladas aumenta en 118.74 unidades cuando la temporada es verano.
#
# El coeficiente de "season_4" es de 81.14848348, lo que significa que en promedio, cuando todas las otras variables se mantienen constantes, el total de bicicletas alquiladas aumenta en 81.15 unidades cuando la temporada es otoño.
#
# El coeficiente de "hour" es de 10.6280633, lo que significa que en promedio, cuando todas las otras variables se mantienen constantes, el total de bicicletas alquiladas aumenta en 10.63 unidades por cada hora adicional del día.
#
# tiene algunas limitacione, por ejemplo este modelo asume una relación lineal entre las variables independientes y la variable dependiente, lo cual puede no ser cierto en todos los casos, tambien la regresión lineal es sensible a valores atípicos y errores de medición lo que podría afectar la precisión de las predicciones, otra limitación depende como se aplique o según el problema es que el modelo asume supuestos como el de colinealidad, normalidad entre otros.

# %% [markdown]
# ### Punto 4 - Árbol de decisión manual
# En la celda 4 cree un árbol de decisiones para pronosticar la variable "total" iterando **manualmente** sobre las variables "hour" y  "season". El árbol debe tener al menos 6 nodos finales.

# %%
# Celda 4

X = bikes[['hour','season']]
y = bikes['total']

# Definición de parámetros y criterios de parada
max_depth = None
num_pct = 10
max_features = None
min_gain=0.001

# Definición de la función que calcula el gini index
def gini(y):
    if y.shape[0] == 0:
        return 0
    else:
        return 1 - (y.mean()**2 + (1 - y.mean())**2)
    
# Definición de la función gini_imputiry para calular la ganancia de una variable predictora j dado el punto de corte k
def gini_impurity(X_col, y, split):
    
    filter_l = X_col < split
    y_l = y.loc[filter_l]
    y_r = y.loc[~filter_l]
    
    n_l = y_l.shape[0]
    n_r = y_r.shape[0]
    
    gini_y = gini(y)
    gini_l = gini(y_l)
    gini_r = gini(y_r)
    
    gini_impurity_ = gini_y - (n_l / (n_l + n_r) * gini_l + n_r / (n_l + n_r) * gini_r)
    
    return gini_impurity_

# Definición de la función best_split para calcular cuál es la mejor variable y punto de cortepara hacer la bifurcación del árbol
def best_split(X, y, num_pct=10):
    
    features = range(X.shape[1])
    
    best_split = [0, 0, 0]  # j, split, gain
    
    # Para todas las varibles 
    for j in features:
        
        splits = np.percentile(X.iloc[:, j], np.arange(0, 100, 100.0 / (num_pct+1)).tolist())
        splits = np.unique(splits)[1:]
        
        # Para cada partición
        for split in splits:
            gain = gini_impurity(X.iloc[:, j], y, split)
                        
            if gain > best_split[2]:
                best_split = [j, split, gain]
    
    return best_split

# Calcula el numero de nodos finales del arbol
def num_final_nodes(tree):
    return 1 if 'sl' not in tree and 'sr' not in tree else count_leaf_nodes(tree['sl']) + count_leaf_nodes(tree['sr'])

# Definición de la función tree_grow para hacer un crecimiento recursivo del árbol
def tree_grow(X, y, level=0, min_gain=0.001, max_depth=None, num_pct=10):
    
    # Si solo es una observación
    if X.shape[0] == 1:
        tree = dict(y_pred=y.iloc[:1].values[0], y_prob=0.5, level=level, split=-1, n_samples=1, gain=0)
        return tree
    
    # Calcular la mejor división
    j, split, gain = best_split(X, y, num_pct)
    
    # Guardar el árbol y estimar la predicción
    y_pred = int(y.mean() >= 0.5) 
    y_prob = (y.sum() + 1.0) / (y.shape[0] + 2.0)  # Corrección Laplace 
    
    tree = dict(y_pred=y_pred, y_prob=y_prob, level=level, split=-1, n_samples=X.shape[0], gain=gain)
    # Revisar el criterio de parada 
    if gain < min_gain:
        return tree
    if max_depth is not None:
        if level >= max_depth:
            return tree   
        
    if num_final_nodes(tree) >= 6:
        return tree
    
    # Continuar creando la partición
    filter_l = X.iloc[:, j] < split
    X_l, y_l = X.loc[filter_l], y.loc[filter_l]
    X_r, y_r = X.loc[~filter_l], y.loc[~filter_l]
    tree['split'] = [j, split]

    # Siguiente iteración para cada partición
    
    tree['sl'] = tree_grow(X_l, y_l, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    tree['sr'] = tree_grow(X_r, y_r, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    
    return tree

# Aplicación de la función tree_grow
tree_grow(X, y, level=0, min_gain=0.001, max_depth=None, num_pct=10)
# Out:
# {'y_pred': 1,
#  'y_prob': 191.53903379867745,
#  'level': 0,
#  'split': [0, 8.0],
#  'n_samples': 10886,
#  'gain': 18268.811823533004,
#  'sl': {'y_pred': 1,
#   'y_prob': 55.40711902113459,
#   'level': 1,
#   'split': [0, 7.0],
#   'n_samples': 3594,
#   'gain': 7207.700659959655,
#   'sl': {'y_pred': 1,
#    'y_prob': 32.561604584527224,
#    'level': 2,
#    'split': [0, 6.0],
#    'n_samples': 3139,
#    'gain': 646.8008927589567,
#    'sl': {'y_pred': 1,
#     'y_prob': 25.15934475055845,
#     'level': 3,
#     'split': [0, 2.0],
#     'n_samples': 2684,
#     'gain': 382.8088308604629,
#     'sl': {'y_pred': 1,
#      'y_prob': 44.41383095499451,
#      'level': 4,
#      'split': [1, 2.0],
#      'n_samples': 909,
#      'gain': 291.4004681825131,
#      'sl': {'y_pred': 1,
#       'y_prob': 23.32456140350877,
#       'level': 5,
#       'split': [0, 1.0],
#       'n_samples': 226,
#       'gain': 45.41972746495435,
#       'sl': {'y_pred': 1,
# ...

# %% [markdown]
# ### Punto 5 - Árbol de decisión con librería
# En la celda 5 entrene un árbol de decisiones con la **librería sklearn**, usando las variables predictoras "season" y "hour" y calibre los parámetros que considere conveniente para obtener un mejor desempeño. Recuerde dividir los datos en conjuntos de entrenamiento y validación para esto. Comente el desempeño del modelo con alguna métrica de desempeño de modelos de regresión y compare desempeño con el modelo del punto 3.

# %%
# Celda 5

# Partimos la muestra en train y test 70 - 30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# definimos el modelo
dtr = DecisionTreeRegressor()

# definimos los hiperparámetros que queremos probar
param_grid = {
    "max_depth": [7, 9, 10, None],
    "min_samples_split": [0.5, 1, 2, 4],
    "min_samples_leaf": [0.5, 1, 2],
    "criterion": ["friedman_mse"]
}

# realizamos la búsqueda en rejilla
grid_search = GridSearchCV(dtr, param_grid=param_grid, cv=10, n_jobs=-1)
grid_search.fit(X_train, y_train)

# imprimimos los mejores hiperparámetros y la puntuación del modelo
print("Mejores hiperparámetros:", grid_search.best_params_)
print("Puntuación del modelo:", grid_search.best_score_)

best_model_dtr = grid_search.best_estimator_

# Predicción en los datos de entrenamiento
y_train_pred = best_model_dtr.predict(X_train)

# Predicción en los datos de prueba
y_test_pred = best_model_dtr.predict(X_test)

# Calcular el MSE en los datos de entrenamiento y prueba
mse_train2 = mean_squared_error(y_train, y_train_pred)
mse_test2 = mean_squared_error(y_test, y_test_pred)

print("El valor del MSE en los datos de entrenamiento es:", mse_train2)
print("El valor del MSE en los datos de prueba es:", mse_test2)

# Visualizar el árbol generado
plt.figure(figsize=(10, 6))
plot_tree(best_model_dtr, feature_names=X_train.columns, filled=True)
plt.show()
# Out:
# Mejores hiperparámetros: {'criterion': 'friedman_mse', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Puntuación del modelo: 0.5972360286349248
# El valor del MSE en los datos de entrenamiento es: 12696.598025176634
# El valor del MSE en los datos de prueba es: 13184.060273446574

# %%
# Comparacion Modelos LinearRegression - DecisionTreeRegressor
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("Comparación de modelos")
ejeX = ['Reg-lineal-Train','Reg-lineal-Test','DecisionTreeReg-Train','DecisionTreeReg-Test']
ejeY = [mse_train.round(2), mse_test.round(2), mse_train2.round(2), mse_test2.round(2)]
ax.bar(ejeX,ejeY)
def addlabels(x,y,plotP):
    for i in range(len(x)):
        plotP.text(i,y[i],y[i])
addlabels(ejeX,ejeY,plt)
plt.show()

# %% [markdown]
# Los resultados indican que el modelo de árbol de decisión proporcionó un MSE de 12696.6 para test que el modelo de regresión lineal 25217.58 para test en este caso particular. Esto podría deberse a que la relación entre las variables predictoras y la variable objetivo es no lineal o debido a interacciones complejas entre las variables predictoras. Sin embargo, es importante tener en cuenta que los modelos de árbol de decisión pueden ser más propensos a overfitting en este caso consideramos que el modeleo se ajusta bien a los datos de test como a los de entrenamiento ya que las diferencias entre los MSE no es tan significativa 9,6%

# %% [markdown]
# ## Parte B - Métodos de ensamblajes
# En esta parte del taller se usará el conjunto de datos de Popularidad de Noticias Online. El objetivo es predecir si la notica es popular o no, la popularidad está dada por la cantidad de reacciones en redes sociales. Para más detalles puede visitar el siguiente enlace: [datos](https://archive.ics.uci.edu/ml/datasets/online+news+popularity).

# %% [markdown]
# ### Datos popularidad de noticias

# %%
# Lectura de la información de archivo .csv
df = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/mashable.csv', index_col=0)
df.head()

# %%
# Definición variable de interes y variables predictoras
X = df.drop(['url', 'Popular'], axis=1)
y = df['Popular']
y.mean()

# %%
# División de la muestra en set de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Punto 6 - Árbol de decisión y regresión logística
# En la celda 6 construya un árbol de decisión y una regresión logística. Para el árbol calibre al menos un parámetro y evalúe el desempeño de cada modelo usando las métricas de Accuracy y F1-Score.

# %%
# Celda 6

# %% [markdown]
# ### Punto 7 - Votación Mayoritaria
# En la celda 7 elabore un esamble con la metodología de **Votación mayoritaria** compuesto por 300 muestras bagged para cada uno de los siguientes escenarios:
#
# -100 árboles de decisión donde max_depth tome un valor de su elección\
# -100 árboles de decisión donde min_samples_leaf tome un valor de su elección\
# -100 regresiones logísticas
#
# Evalúe cada uno de los tres modelos de manera independiente utilizando las métricas de Accuracy y F1-Score, luego evalúe el ensamble de modelos y compare los resultados.

# %%
# Celda 7

# %% [markdown]
# ### Punto 8 - Votación Ponderada
# En la celda 8 elabore un ensamble con la metodología de **Votación ponderada** compuesto por 300 muestras bagged para los mismos tres escenarios del punto 7. Evalúe los modelos utilizando las métricas de Accuracy y F1-Score

# %%
# Celda 8

# %% [markdown]
# ### Punto 9 - Comparación y análisis de resultados
# En la celda 9 comente sobre los resultados obtenidos con las metodologías usadas en los puntos 7 y 8, compare los resultados y enuncie posibles ventajas o desventajas de cada una de ellas.

# %%
# Celda 9
